# %% [markdown]
# # Outline
#
# Levels of validation
# * Schema Validation
# * is the template a valid CAP template - version, release, other metadata
# * Does your data dictionary accurately reflect all the data and metadata that is in the empty CAP template?
# * Authentication and authorization for blank templates and completed form - are you allowed to see the data
# * Validation errors - test cases and validation messages
# * Validate attributes in FDF-R - validate against FDF to check if the rules specified in the FDF are followed
#     * e.g. minCard, maxCard, repeat numbers, readOnly, newData, changedData
# * list all the attributes that require extra validation so that code can be written against descriptions to validate
#
# ## necessary features
# * what are the possible codes in the NAACCR OBR? (can start with tables in the program that updated quarterly)
# * Check if there is a repeat - is the integer in the appropriate place in the ID?
# * pull out baseURI to identify custom elements from SDC form (in the NAACCR Vol V message would need to validate it against the ID - note that a custom property or element may no be present in the NAACCR Vol V)
# * Detect non-eCP OBXs which should be in a separate OBR e.g. a gross report that was part of the eCP OBR, but should be separated
# * need the template in order to apprioriately validate that the rule was followed - custom rules which are not part of the template should generate a warning

# %% [markdown]
# # Next steps:
# 1. Sample V2 messages from Pete in NAACCR Vol V format
# 2. Create a new solution/project which imports the SDC OM and [nHapi project](https://github.com/nHapiNET/nHapi)
# 3. Load sample messages into nHapi object model
# 4. Parse HL7 messages, walk tree, and print out everything that we find (follow Raghavan's general outline from [python validator](https://github.com/IHE-SDC-WG/NAACCRVolV-SDCtoolkit))
# 5. Create a new empty SDC Form Design Object
# 6. Populate the SDC Form Design Object with information - locate the proper OBR and grab the OBXs and the SPMs to hydrate the SDC object model
# 7. ???
# 8. Build validator

# %% [markdown]
# ## Validating SDC Forms
#
# Many SDC forms and form responses can be easily validated using the [SDC Schema](). Validation is essential to ensuring that the form content and structure are appropriate. For Form Responses this validation step is essential to ensure that data has been placed correctly within the form.
#
# ### Validating with the Schema

# %% [markdown]
# ### Attributes For Special Validation
#
# The following tables list and describe the elements which require additional validation beyond basic schema validation. These elements may require validation using the SDC Object Model or other regular programming to confirm the element's rule has been implemented correctly in the Form Design File (FDF) and used correctly in the form response. Most of these attributes reflect rules that have been implemented in the form.
#
# To do this kind of validation, a program would need to read the original FDF and compare the attributes which require additional validation and how they were used in the form response.
#
# An * indicates that the item is critical for an initial version of the validator. ** indicates that the element should be validated in a future version.
#
# #### Text After Response
#
# | Attribute Name   | Description                                                                                           | What needs to be validated                                                                                  |Default Value|
# |------------------|-------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------|--------------|
# | *val    |||true          |
#
# #### Response Units
#
# | Attribute Name   | Description                                                                                           | What needs to be validated                                                                                  |Default Value|
# |------------------|-------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------|--------------|
# | *val    |||true          |
# | *system     |                                     |                        |true          |
#
# #### General Attributes
#
# ##### Attributes Supported in Validator
#
# | Attribute Name   | Description                                                                                           | What needs to be validated                                                                                  |Default Value|
# |------------------|-------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------|--------------|
# | *mustImplement    | Indicates whether the specified element must be implemented in the form.                             | Validate that the element is implemented in the form as required.                                            |true          |
# | *showInReport     | Specifies whether this element should be included in the report.                                     | Validate that the element is included in the report based on the specified criteria.                        |true          |
#
# ##### Attributes to be supported in future version
#
# | Attribute Name   | Description                                                                                           | What needs to be validated                                                                                  |Default Value|
# |------------------|-------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------|--------------|
# | setEnabled       | Enable this attribute when the specified condition evaluates to true.                                 | Validate that the condition is correctly evaluated and the attribute is enabled only when the condition is met. |false         |
# | setExpanded      | Expand this element when the specified condition evaluates to true.                                   | Validate that the element is expanded only when the specified condition is met.                              |              |
# | completionStatus | Status indicating whether the completion criteria for this element have been met.                     | Validate that the completion status accurately reflects whether the element's criteria have been met.        |              |
# | IfAttributes     | Conditional attributes that apply when the specified condition is met.                                | Validate that the conditional attributes are correctly applied when the condition is satisfied.             |              |
#
# #### Section or Question Attributes
#
# ##### Attributes Supported in Validator
#
# | Attribute Name        | Description                                                                                            | What needs to be validated                                                                                      |Default Value|
# |-----------------------|--------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------|--------------|
# | *minCard              | Minimum cardinality for the element.                                                                   | Validate that the element meets the minimum cardinality requirement.                                             |              |
# | *maxCard              | Maximum cardinality for the element.                                                                   | Validate that the element does not exceed the maximum cardinality requirement.                                    |              |
#
# ##### Attributes to be supported in future version
#
# | Attribute Name             | Description                                                                                            | What needs to be validated                                                                                      |Default Value|
# |----------------------------|--------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------|--------------|
# | EventType                  | Specifies the type of event that triggers actions.                                                      | Validate that actions are correctly triggered based on the specified event types.                                 |              |
# | PredActionType             | Specifies the type of predicate action.                                                                 | Validate that predicate actions are correctly executed based on specified conditions.                            |              |
# | OnEventType                | Specifies actions to take when certain events occur.                                                    | Validate that the correct actions are taken when the specified events occur.                                      |              |
# | actType                    | Specifies the type of action to be performed.                                                           | Validate that the action is performed accurately based on the specified type.                                     |              |
# | PredAlternativesType       | Specifies alternative actions based on conditions.                                                      | Validate that alternative actions are correctly executed based on the specified conditions.                      |              |
# | PredGuardType              | Specifies guard conditions for actions.                                                                 | Validate that guard conditions are accurately evaluated and applied to actions.                                  |              |
# | ActionsType                | Specifies a collection of actions.                                                                     | Validate that the collection of actions is correctly executed as intended.                                       |              |
# | onlyIf                     | Specifies that the element is applicable only if the given condition is met.                           | Validate that the element is applied only when the specified condition is met.                                    |
#
# ##### Action Attributes
#
# | Attribute Name             | Description                                                                                            | What needs to be validated                                                                                      |Default Value|
# |----------------------------|--------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------|--------------|
# | ActSetAttrValueScriptType  | Script type for setting attribute values dynamically.                                                  | Validate that the script correctly sets attribute values dynamically as intended.                                |              |
# | ScriptCodeAnyType          | Generic script code that can be used for various actions.                                               | Validate that the script code performs the intended actions accurately.                                          |              |
# | ActSetBoolAttributeValueCodeType | Script for setting boolean attribute values.                                                  | Validate that the script correctly sets boolean attribute values based on specified conditions.                  |              |
# | ActShowMessageType         | Action type for displaying messages to the user.                                                        | Validate that the correct messages are displayed to the user under the appropriate conditions.                   |              |
# | ActShowFormType            | Action type for displaying forms to the user.                                                           | Validate that the correct forms are displayed to the user as specified.                                          |              |
# | ActSaveResponsesType       | Action type for saving user responses.                                                                 | Validate that user responses are saved accurately and as intended.                                               |              |
# | ActShowReportType          | Action type for generating and displaying reports.                                                      | Validate that reports are generated and displayed accurately based on the specified criteria.                    |              |
# | ActPreviewReportType       | Action type for previewing reports before finalization.                                                 | Validate that reports can be previewed correctly before they are finalized.                                       |              |
# | ActSendReportType          | Action type for sending reports to specified recipients.                                                | Validate that reports are sent to the correct recipients under the specified conditions.                         |              |
# | ActSendMessageType         | Action type for sending messages to specified recipients.                                               | Validate that messages are sent to the correct recipients under the appropriate conditions.                      |              |
# | ActValidateFormType        | Action type for validating the form's data.                                                             | Validate that the form's data is accurately validated based on specified rules.                                   |              |
# | ActInjectType              | Action type for injecting data into the form.                                                           | Validate that data is injected correctly into the form as intended.                                               |              |
# | ActAddCodeType             | Action type for adding code values to the form.                                                         | Validate that code values are added accurately to the form based on specified criteria.                          |              |
# | ActActionType              | Generic action type that can be customized for various purposes.                                        | Validate that the generic action performs the intended operations accurately.                                     |              |
#
# ##### Attributes for Matching Questions
#
# | Attribute Name        | Description                                                                                            | What needs to be validated                                                                                      |Default Value|
# |-----------------------|--------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------|--------------|
# | MatchQuestions        | Specifies conditions to match questions for validation.                                                | Validate that questions are matched correctly based on specified conditions.                                      |              |
# | hasSelectionsGTE      | Specifies the minimum number of selections required.                                                   | Validate that the minimum number of selections is met.                                                             |              |
# | hasSelectionsLTE      | Specifies the maximum number of selections allowed.                                                    | Validate that the maximum number of selections is not exceeded.                                                    |              |
# | hasSelectionsExact    | Specifies the exact number of selections required.                                                     | Validate that the exact number of selections is made.                                                              |              |
# | hasResponse           | Specifies whether a response is present.                                                               | Validate that a response is present as required.                                                                  |              |
# | hasValueLT            | Specifies that the value should be less than a given threshold.                                        | Validate that the value is less than the specified threshold.                                                     |              |
# | hasValueLTE           | Specifies that the value should be less than or equal to a given threshold.                            | Validate that the value is less than or equal to the specified threshold.                                          |              |
# | hasValueGT            | Specifies that the value should be greater than a given threshold.                                     | Validate that the value is greater than the specified threshold.                                                  |              |
# | hasValueGTE           | Specifies that the value should be greater than or equal to a given threshold.                         | Validate that the value is greater than or equal to the specified threshold.                                       |              |
# | hasAssociatedValueEQ  | Specifies that the associated value should be equal to a given value.                                  | Validate that the associated value is equal to the specified value.                                                |              |
# | hasAssociatedValueLT  | Specifies that the associated value should be less than a given value.                                 | Validate that the associated value is less than the specified value.                                               |              |
# | hasAssociatedValueLTE | Specifies that the associated value should be less than or equal to a given value.                     | Validate that the associated value is less than or equal to the specified value.                                   |              |
# | hasAssociatedValueGT  | Specifies that the associated value should be greater than a given value.                              | Validate that the associated value is greater than the specified value.                                            |              |
# | hasAssociatedValueGTE | Specifies that the associated value should be greater than or equal to a given value.                  | Validate that the associated value is greater than or equal to the specified value.                                |
# | *isReadOnly           | Specifies whether the element is read-only.                                                            | Validate that the element is read-only based on specified conditions.                                              |
# | ConditionalActions    | Specifies actions that are conditional on certain criteria.                                            | Validate that actions are correctly executed based on specified conditions.                                        |
#
# Do these stylistic things need a validator?
#
# - colTextDelimiter
# - numCols
# - storedCol
#
# #### Actions
#
# | Attribute Name            | Description                                                                                     | What needs to be validated                                                                                      |Default Value|
# |---------------------------|-------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------|--------------|
# | actVisible                | Specifies whether the element should be visible based on conditions.                            | Validate that the element's visibility is correctly controlled based on specified conditions.                    |              |
# | actEnable                 | Specifies whether the element should be enabled based on conditions.                            | Validate that the element's enablement is correctly controlled based on specified conditions.                    |              |
# | actMinCard                | Minimum cardinality for actions.                                                                | Validate that actions meet the minimum cardinality requirement.                                                  |              |
# | actMaxCard                | Maximum cardinality for actions.                                                                | Validate that actions do not exceed the maximum cardinality requirement.                                          |              |
# | actActivate               | Action to activate specified elements.                                                          | Validate that the correct elements are activated based on specified criteria.                                     |              |
# | actSelect                 | Action to select specified elements.                                                            | Validate that the correct elements are selected based on specified criteria.                                      |              |
# | actDeleteResponse         | Action to delete specified responses.                                                           | Validate that specified responses are deleted accurately as intended.                                             |              |
# | actReadOnly               | Specifies whether the element should be read-only based on conditions.                          | Validate that the element's read-only status is correctly controlled based on specified conditions.               |              |
# | actStyleClass             | Specifies style classes to apply to the element.                                                | Validate that the specified style classes are correctly applied to the element.                                   |              |
# | actSetTitleText           | Action to set the title text of the element.                                                    | Validate that the title text is correctly set for the element.                                                    |              |
# | actSetBase64HTML          | Action to set the HTML content of the element using Base64 encoding.                            | Validate that the HTML content is correctly set using Base64 encoding as intended.                                |              |
# | actSetCode                | Action to set the code value of the element.                                                    | Validate that the code value is correctly set for the element.                                                    |              |
# | actSetCodeSystem          | Action to set the code system for the element.                                                  | Validate that the code system is correctly set for the element.                                                   |              |
# | actSetVal                 | Action to set the value of the element.                                                         | Validate that the value is correctly set for the element.                                                         |              |
# | actSetAssociatedValue     | Action to set associated values for the element.                                                | Validate that associated values are correctly set for the element.                                                |              |
# | actSetValFromRef          | Action to set the value of the element from a reference.                                        | Validate that the value is correctly set from the specified reference.                                             |              |
# | actSetAssociatedValueFromRef | Action to set associated values from a reference.                                            | Validate that associated values are correctly set from the specified reference.                                   |
#
# #### ListItem Attributes
#
# ##### Attributes Supported in Validator
#
# | Attribute Name              | Description                                                                                     | What needs to be validated                                                                                      |Default Value|
# |-----------------------------|-------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------|--------------|
# | *selectionDeselectsSiblings | Specifies whether selecting an item deselects its sibling items.                                | Validate that sibling items are correctly deselected when an item is selected.                                   |              |
# | *omitWhenSelected           | Specifies whether to omit the item when it is selected.                                         | Validate that the item is correctly omitted from the human readable report when selected, but the data should still be present in the transmission (whether SDC Xml, HL7 V2, Database, etc.). |              |
#
# ##### Attributes to be supported in future version
#
# | Attribute Name              | Description                                                                                     | What needs to be validated                                                                                      |Default Value|
# |-----------------------------|-------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------|--------------|
# | **selectionSelectsListItems | Specifies whether selecting an item selects other list items.                                   | Validate that other list items are correctly selected when an item is selected.                                  |              |
# | **minSelections             | Specifies the minimum number of selections required.                                            | Validate that the minimum number of selections is met.                                                           |              |
# | **maxSelections             | Specifies the maximum number of selections allowed.                                             | Validate that the maximum number of selections is not exceeded.                                                  |              |
#
# ##### Additional ListItem Attributes
#
# | Attribute Name              | Description                                                                                     | What needs to be validated                                                                                      |Default Value|
# |-----------------------------|-------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------|--------------|
# | RuleAutoSelectType          | Rule type for automatically selecting items based on conditions.                                | Validate that items are automatically selected based on specified conditions.                                   |              |
# | RuleAutoActivateType        | Rule type for automatically activating items based on conditions.                               | Validate that items are automatically activated based on specified conditions.                                  |              |
# | PredSelectionTestType       | Predicate type for selection tests.                                                             | Validate that selection tests are correctly performed based on specified predicate conditions.                  |              |
# | PredSingleSelectionSetsType | Predicate type for single selection sets.                                                       | Validate that single selection sets are correctly applied based on specified conditions.                        |              |
# | OnSelect                    | Actions to perform when an item is selected.                                                    | Validate that the correct actions are performed when an item is selected.                                        |              |
# | OnDeselect                  | Actions to perform when an item is deselected.                                                  | Validate that the correct actions are performed when an item is deselected.                                      |
# | SelectIf                    | Conditions under which an item should be selected.                                              | Validate that items are selected based on specified conditions.                                                  |
# | DeselectIf                  | Conditions under which an item should be deselected.                                            | Validate that items are deselected based on specified conditions.                                                |
# | *selectionDisablesChildren  | Specifies whether selecting an item disables its child elements.                                | Validate that child elements are correctly disabled when an item is selected.                                    |
# | selectionActivatesItems     | Specifies whether selecting an item activates other items.                                      | Validate that other items are correctly activated when an item is selected.                                      |
# | selectedItemSet             | Specifies a set of items that should be selected.                                               | Validate that the specified set of items is correctly selected.                                                  |
# | setVisibility               | Specifies the visibility of the item based on conditions.                                       | Validate that the item's visibility is correctly controlled based on specified conditions.                       |
# | MatchListItems              | Specifies conditions to match list items for validation.                                        | Validate that list items are matched correctly based on specified conditions.                                     |
#
# #### Response Reporting Attributes
#
# | Attribute Name            | Description                                                                                     | What needs to be validated                                                                                      |Default Value|
# |---------------------------|-------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------|--------------|
# | associatedValueType       | Specifies the type of associated value.                                                         | Validate that the associated value type is correctly applied as intended.                                       |              |
# | associatedValue           | Specifies the associated value for the element.                                                 | Validate that the associated value is correctly set for the element.                                            |              |
# | newData                   | Indicates new data that can be applied to list items and other response types.                  | Validate that new data is correctly applied to list items and other response types as intended.                 |              |
